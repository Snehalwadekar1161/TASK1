# %% [markdown]
# # Task 6: Prediction using Decision Tree Algorithm

# %% [markdown]
# ### Description: Create The Decision  Tree Classifier And Visualize It Graphically

# %% [markdown]
# **Name: Snehal wadekar**

# %% [markdown]
# Dataset: https://bit.ly/3kXTdox

# %% [markdown]
# **import libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %% [markdown]
# **import dataset**

# %%
iris=pd.read_csv('Iris1.csv')

iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **Checking null values**

# %%
 iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import seaborn as sns
plt.figure (figsize=(6,10), dpi=100, facecolor='w')
sns.pairplot(iris,hue="Species")

# %% [markdown]
# **Train And Test dataset**

# %%
train,test=train_test_split(iris,test_size=0.3)
print(train.shape)
print(test.shape)
# Out:
# (105, 5)
# (45, 5)

# %%
train_x=train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
train_y=train.Species
test_x=test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
test_y=test.Species

# %% [markdown]
# ## Defining the decision tree Algorithm

# %%
dtree=DecisionTreeClassifier(max_depth=3,random_state=1)
model_all_params=DecisionTreeClassifier().fit(train_x,train_y)

print("Descision Tree Classifer Created")
# Out:
# Descision Tree Classifer Created

# %%
cn=iris.Species
fn=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

# %%
plt.figure(figsize=(30,30))
plot_tree(model_all_params,feature_names=fn,class_names=cn,filled=True)
# Out:
# [Text(837.0, 1494.8999999999999, 'PetalWidthCm <= 0.8\ngini = 0.665\nsamples = 105\nvalue = [35, 32, 38]\nclass = Iris-setosa'),
#  Text(669.6, 1223.1, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]\nclass = Iris-setosa'),
#  Text(1004.4000000000001, 1223.1, 'PetalWidthCm <= 1.75\ngini = 0.496\nsamples = 70\nvalue = [0, 32, 38]\nclass = Iris-setosa'),
#  Text(669.6, 951.3, 'PetalLengthCm <= 5.3\ngini = 0.114\nsamples = 33\nvalue = [0, 31, 2]\nclass = Iris-setosa'),
#  Text(502.20000000000005, 679.4999999999999, 'SepalLengthCm <= 4.95\ngini = 0.061\nsamples = 32\nvalue = [0, 31, 1]\nclass = Iris-setosa'),
#  Text(334.8, 407.6999999999998, 'PetalWidthCm <= 1.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Iris-setosa'),
#  Text(167.4, 135.89999999999986, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Iris-setosa'),
#  Text(502.20000000000005, 135.89999999999986, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-setosa'),
#  Text(669.6, 407.6999999999998, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]\nclass = Iris-setosa'),
#  Text(837.0, 679.4999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-setosa'),
#  Text(1339.2, 951.3, 'PetalLengthCm <= 4.85\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = Iris-setosa'),
#  Text(1171.8, 679.4999999999999, 'SepalLengthCm <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Iris-setosa'),
#  Text(1004.4000000000001, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Iris-setosa'),
#  Text(1339.2, 407.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Iris-setosa'),
#  Text(1506.6000000000001, 679.4999999999999, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = Iris-setosa')]
